# %%
import pandas as pd
from src.utils import load_reviews_csv, load_metadata_json
from src.preprocessing import load_data, load_metadata

# %%
def load_data_clean(file_name: str):
    review_path = "./data_cleaned/reviews_cleaned_" + file_name + ".csv"
    metadata_path = "./data_cleaned/metadata_cleaned_" + file_name + ".json"

    review = load_reviews_csv(review_path)
    metadata = load_metadata_json(metadata_path)

    return review, metadata

# %%
review, metadata = load_data_clean('Digital_Music')

# %%
review
# Out:
#        overall  verified      reviewerID        asin  \
# 0          5.0      True  A2HVNCQUR2J4NL  0001526146
# 1          5.0      True   A50DSLM71EAVO  0001526146
# 2          5.0      True  A33NJBWHVS6HKX  0001526146
# 3          5.0      True  A3BQ84G90BRVSG  0001526146
# 4          5.0      True  A150DKJ7BD9A4L  0001526146
# ...        ...       ...             ...         ...
# 92505      5.0     False   AR6WL9TVHIV3G  B01HH68B96
# 92506      5.0     False   AKZO56QWK7N76  B01HH68B96
# 92507      5.0      True  A1T4M8J6BKRPUI  B01HIT3KZC
# 92508      5.0      True  A2746S1ODNDAVH  B01HIT3KZC
# 92509      5.0      True  A3M26ROGGIGU40  B01HIT3KZC
#
#                                               reviewText  \
# 0      this is music from my younger years that i as ...
# 1      i love dallas holms music and voice thank you ...
# 2      a great collection of dallas s early music eas...
# 3         bought this for my daughter she has enjoyed it
# ...

# %%
metadata.dtypes
# Out:
# description    string[python]
# title          string[python]
# also_buy               object
# brand          string[python]
# rank                  float32
# also_view              object
# price                 float32
# asin           string[python]
# details        string[python]
# dtype: object

# %%
review.head(100)
# Out:
#     overall  verified      reviewerID        asin  \
# 0       5.0      True  A2HVNCQUR2J4NL  0001526146
# 1       5.0      True   A50DSLM71EAVO  0001526146
# 2       5.0      True  A33NJBWHVS6HKX  0001526146
# 3       5.0      True  A3BQ84G90BRVSG  0001526146
# 4       5.0      True  A150DKJ7BD9A4L  0001526146
# ..      ...       ...             ...         ...
# 95      5.0      True  A21OK9653AUSIM  1882513274
# 96      5.0     False  A12C3HZOWOC23U  1882513274
# 97      5.0     False  A126V6ZJ6LHRMP  1929243464
# 98      2.0     False  A1MOOJYDP1A6WJ  1929243464
# 99      5.0     False  A1Q3A8WY5S39X6  1929243464
#
#                                            reviewText  \
# 0   this is music from my younger years that i as ...
# 1   i love dallas holms music and voice thank you ...
# 2   a great collection of dallas s early music eas...
# 3      bought this for my daughter she has enjoyed it
# 4   many awesome tracks though rise again is the o...
# ...

# %%
# check for metadata row where asin = '0001388703'
metadata_raw[metadata_raw['asin'] == '0001388703']
# Out:
#   category tech1 description fit                          title  \
# 3       []                []      So You Wanna Go Back to Egypt
#
#                                             also_buy tech2        brand  \
# 3  [B0000275QQ, 0001393774, 0001388312, B0016CP2G...        Keith Green
#
#   feature                      rank  \
# 3      []  203,263 in CDs & Vinyl (
#
#                                            also_view  \
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
#
#                                             main_cat similar_item date  \
# 3  <img src="https://images-na.ssl-images-amazon....
#
#     price        asin imageURL imageURLHighRes details
# 3  $13.01  0001388703       []              []     NaN
